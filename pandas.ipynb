# %% [markdown]
# # What is Pandas?
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# What Can Pandas Do?
# Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
# What is average value?
# Max value?
# Min value?
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %%
#! pip install pandas

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
mydataset ={
    'cars': ["BMW" , "Volvo" , "Ford"],
    'passings':[3,7,1]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         1

# %% [markdown]
# What is a Series?
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[0])
# Out:
# 1

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)

print(myvar["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 7

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('Cleaned_Students_Performance.csv')

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 0         0        group B           bachelor's degree      1
# 1         0        group C                some college      1
# 2         0        group B             master's degree      1
# 3         1        group A          associate's degree      0
# 4         1        group C                some college      1
# ..      ...            ...                         ...    ...
# 995       0        group E             master's degree      1
# 996       1        group C                 high school      0
# 997       0        group C                 high school      0
# 998       0        group D                some college      1
# 999       0        group D                some college      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 0                          0          72             72             74
# 1                          1          69             90             88
# ...

# %%
print(df.to_string())
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  test_preparation_course  math_score  reading_score  writing_score  total_score  average_score
# 0         0        group B           bachelor's degree      1                        0          72             72             74          218      72.666667
# 1         0        group C                some college      1                        1          69             90             88          247      82.333333
# 2         0        group B             master's degree      1                        0          90             95             93          278      92.666667
# 3         1        group A          associate's degree      0                        0          47             57             44          148      49.333333
# 4         1        group C                some college      1                        0          76             78             75          229      76.333333
# ...

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df=pd.read_csv('Cleaned_Students_Performance.csv')

print(df)
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 0         0        group B           bachelor's degree      1
# 1         0        group C                some college      1
# 2         0        group B             master's degree      1
# 3         1        group A          associate's degree      0
# 4         1        group C                some college      1
# 5         0        group B          associate's degree      1
# 6         0        group B                some college      1
# 7         1        group B                some college      0
# 8         1        group D                 high school      0
# 9         0        group B                 high school      0
# 10        1        group C          associate's degree      1
# 11        1        group D          associate's degree      1
# 12        0        group B                 high school      1
# 13        1        group A                some college      1
# ...

# %%
print(df.head(10))
# Out:
#    gender race_ethnicity parental_level_of_education  lunch  \
# 0       0        group B           bachelor's degree      1
# 1       0        group C                some college      1
# 2       0        group B             master's degree      1
# 3       1        group A          associate's degree      0
# 4       1        group C                some college      1
# 5       0        group B          associate's degree      1
# 6       0        group B                some college      1
# 7       1        group B                some college      0
# 8       1        group D                 high school      0
# 9       0        group B                 high school      0
#
#    test_preparation_course  math_score  reading_score  writing_score  \
# 0                        0          72             72             74
# 1                        1          69             90             88
# 2                        0          90             95             93
# ...

# %%
print(df.tail())
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 995       0        group E             master's degree      1
# 996       1        group C                 high school      0
# 997       0        group C                 high school      0
# 998       0        group D                some college      1
# 999       0        group D                some college      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 995                        1          88             99             95
# 996                        0          62             55             55
# 997                        1          59             71             65
# 998                        1          68             78             77
# 999                        0          77             86             86
#
#      total_score  average_score
# 995          282      94.000000
# 996          172      57.333333
# 997          195      65.000000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   int64
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   int64
#  4   test_preparation_course      1000 non-null   int64
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
#  8   total_score                  1000 non-null   int64
#  9   average_score                1000 non-null   float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 78.3+ KB
# None

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('Building_Permits.csv')
# Out:
# C:\Users\Divyansh\AppData\Local\Temp\ipykernel_25652\2651529629.py:5: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Building_Permits.csv')

# %%
df
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
missing_values_count = df.isnull().sum()

missing_values_count[0:10]

df.plot(kind = 'scatter' , x = 'Lot' , y = 'Street Number' ,colormap='viridis')

df.plot(kind = 'hist' , x = 'Lot' , y = 'Street Number' ,colormap='viridis')
# Out:
# c:\Users\Divyansh\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: ylabel='Frequency'>

# %%
missing_values_count[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
total_cells = np.product(df.shape)

total_missing = missing_values_count.sum()

percent_missing = (total_missing/total_cells) * 100

print(percent_missing)
# Out:
# 26.26002315058403

# %%
missing_values_count[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %%
columns_with_na_dropped = df.dropna(axis=1)

columns_with_na_dropped.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
print("Columns in original dataset: %d \n" % df.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 43
#
# Columns with na's dropped: 12

# %%
dfa=columns_with_na_dropped.fillna(0)

# %%
dfa
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# ...

# %%
dfa.plot(kind = 'scatter' , x = 'Lot' , y = 'Street Number' ,colormap='viridis')

dfa.plot(kind = 'hist' , x = 'Lot' , y = 'Street Number' ,colormap='viridis')
# Out:
# c:\Users\Divyansh\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: ylabel='Frequency'>
